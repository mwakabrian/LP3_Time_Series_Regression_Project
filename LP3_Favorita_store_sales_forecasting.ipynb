# %% [markdown]
# ## **FAVORITA STORES SALES TIME SERIES FORECASTING** ##
#
# ## **Introduction**
#
# *Corporacion Favorita is an Ecuador based company engaged in the organization, installation and administration of stores, markets and supermaektes. The business areas in which the organiztion is involved are Commercial area, Real estate area and Industrial area.* *The company aims to optimize its inventory management by accurately forecasting the product demand in various locations. By accurate demand forecasting, the company will be able to maintain optimal inventory levels, reduce wastage By aligning it supply with the customers demand, the company can enhance customer satisfaction, increase their sales revenue and reduce their carrying costs.*
# *The key stakehoders are the Inventory managers, suppy chain managers, and store managers who will rely on the model of this project to make informed decisions related to purchasing, replenishment, and stock allocation.*
#
# ## **Business Understanding**
#
# *Businesses must forecast product demand to compete. This is especially true for brick-and-mortar grocery stores, which must dance delicately with how much inventory to buy. Predict a little over, and grocers are stuck with overstocked, perishable goods. Guess a little under, and popular items quickly sell out, leading to lost revenue and upset customers. More accurate forecasting, thanks to machine learning, could help ensure retailers make the customers happy by having just enough of the right products at the right time. Everyone hates when their favourite item is out of stock.*
#
# ## **Statement Of The Problem**
#
# *Businesses must forecast product demand to compete. This is especially true for brick-and-mortar grocery stores, which must dance delicately with how much inventory to buy. Predict a little over, and grocers are stuck with overstocked, perishable goods. Guess a little under, and popular items quickly sell out, leading to lost revenue and upset customers.* *Current subjective forecasting methods for retail have little data to back them up and are unlikely to be automated. The problem becomes even more complex as retailers add new locations with unique needs, new products, ever-transitioning seasonal tastes, and unpredictable changing market conditions.*
#
# *More accurate forecasting, thanks to machine learning, could help ensure retailers make the customers happy by having just enough of the right products at the right time. Everyone hates when their favourite item is out of stock. For grocery stores, more accurate forecasting can decrease food waste related to overstocking and improve customer satisfaction.*
#
# ## **Project Description**
#
# *In this project, we will use regression, a specific type of supervised machine learning that focuses on predicting continuous numerical values, to predict grocery store sales for the thousands of product families sold at Favorita stores located in Ecuador. The training data includes dates, store and product information, whether that item was being promoted, as well as the sales numbers.*
#
# *The primary objective of this machine learning project is to develop an accurate predictive model for forecasting grocery store sales at Favorita stores in Ecuador. This model will help address the challenge faced by brick-and-mortar grocery stores in managing their inventory effectively. The goal is to predict sales for thousands of product families, considering various factors such as dates, store information, product details, and promotional activities. By achieving this objective, we aim to minimize overstocking, reduce food waste, and enhance customer satisfaction by ensuring that the right products are available in the right quantities at the right time.*
#
# ## **The Task**
#
# *For this project, we are dealing with a Time series forecasting problem. Time series forecasting involves predicting unknown values by collecting historical data, preparing it for algorithms to consume, and then predicting the future values based on patterns learned from the historical data. Also, we will build different machine learning models, evaluate the models, test the models, compare performances of the models and select the model that best predicts future grocery sales.*
#
# ## **Project Methodology**
#
# *The CRISP-DM (Cross-Industry Standard Process for Data Mining) framework will guide our project, ensuring a structured and iterative approach to solving the forecasting problem. This framework encompasses phases such as Business Understanding, Data Understanding, Data Preparation, Modeling, Evaluation, Deployment, and Maintenance, allowing us to systematically develop and deploy an effective sales forecasting solution for Favorita stores in Ecuador.*
# *We will explore different machine learning algorithms to determine the most suitable one. Potential models include but are not limited to:*
#
# **1. Time Series Forecasting**: Utilizing techniques such as ARIMA, LSTM, or Prophet to capture temporal patterns and seasonality in sales data.*
#
# **2. Regression Models**: Employing linear regression, decision trees, random forests, or gradient boosting to account for various features like promotional status, product details, and store information.*
# *To assess the performance of the predictive model, we will use metrics such as Root Mean Squared Logarithmic Error (RMSLE), Root Mean Squared Error (RMSE) and Mean Absolute Error (MAE). The errors will be aggregated to evaluate the forecast bias. To be certain whether the model tends to underpredict or overpredict sales, which can be crucial for inventory management.*
#
# ## **Explanation Of Features**
#
# *File Descriptions and Data Field Information*
#
# **train.csv**
#
# *The training data, comprising time series of features store_nbr, family, and onpromotion as well as the target sales.*
#
# *store_nbr identifies the store at which the products are sold.*
#
# *family identifies the type of product sold.*
#
# *sales gives the total sales for a product family at a particular store at a given date. Fractional values are possible since products can be sold in fractional units (1.5 kg of cheese, for instance, as opposed to 1 bag of chips).*
#
# *onpromotion gives the total number of items in a product family that were being promoted at a store at a given date.*
#
# **test.csv**
#
# *The test data, having the same features as the training data. You will predict the target sales for the dates in this file.*
#
# *The dates in the test data are for the 15 days after the last date in the training data.*
#
# **transaction.csv**
#
# *Contains date, store_nbr and transaction made on that specific date.*
#
# **sample_submission.csv**
#
# *A sample submission file in the correct format.*
#
# **stores.csv**
#
# *Store metadata, including city, state, type, and cluster.*
#
# *cluster is a grouping of similar stores.*
#
# **oil.csv**
#
# *Daily oil price which includes values during both the train and test data timeframes. (Ecuador is an oil-dependent country and its economical health is highly vulnerable to shocks in oil prices.)*
#
# **holidays_events.csv**
#
# *Holidays and Events, with metadata.*
#
# ## **Hypothesis**
#
# **Null Hypothesis (H0):**
#
# *"The presence of products on promotion does not have a statistically significant impact on store sales."*
#
# **Alternative Hypothesis (Ha):**
#
# *"There is a statistically significant relationship between the presence of products on promotion and store sales."*
#
# ## **Research Questions**
#
# **1.** *Is the train dataset complete (has all the required dates)?*
#
# **2.** *Which dates have the lowest and highest sales for each year?*
#
# **3.** *Did the earthquake impact sales?*
#
# **4.** *Are certain groups of stores selling more products? (Cluster, city, state, type)*
#
# **5.** *Are sales affected by promotions, oil prices and holidays?*
#
# **6.** *What analysis can we get from the date and its extractable features?*
#
# **7.** *What is the difference between RMSLE, RMSE, MSE (or why is the MAE greater than all of them?)*

# %% [markdown]
# ## **Data Understanding** ##
#
# ## **Installing and Importing  Packages**
#
# **2.1: Installing the necessary libraries**

# %%
# Installing the required libraries for the notebook to accomodate the codes
# pip install pyodbc  
# pip install python-dotenv 
# pip install numpy
# pip install matplotlib
# pip install seaborn
# pip install pandas
# pip install currency_converter
# pip install forex-python
# pip install scipy
# pip install forex-python
# pip install statsmodels

# %% [markdown]
# **2.2: Importing the required Packages**

# %%
# Data manipulation and analysis
import pandas as pd
import numpy as np
from dotenv import dotenv_values

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px


# Machine learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.impute import SimpleImputer
from scipy import stats
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from scipy.stats import boxcox
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_log_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from statsmodels.tsa.api import AutoReg
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV

# Database connection
import pyodbc

# Ignore warnings (optional)
import warnings

# %% [markdown]
# **2.3: Loading the environment variables  from .env file into a dictionary using the values for the credentials set in the '.env' file. Connecting to the Microsoft SQL Server database to retrieve data by creating a connection string to the remote database server**

# %%
# Load environment variables from .env file into a dictionary
environment_variables = dotenv_values('.env')


# Get the values for the credentials you set in the '.env' file
database = environment_variables.get("DATABASE")
server = environment_variables.get("SERVER")
username = environment_variables.get("USERNAME")
password = environment_variables.get("PASSWORD")


connection_string = f"DRIVER={{SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password}"

# Use the connect method of the pyodbc library and pass in the connection string.

connection = pyodbc.connect(connection_string)

# Note that you will not have permissions to insert delete or update this database table. 

# Define SQL queries for each table
query_oil = "SELECT * FROM dbo.oil;"
query_holidays_events = "SELECT * FROM dbo.holidays_events;"
query_stores = "SELECT * FROM dbo.stores;"

# Execute the queries and read data into DataFrames
df_oil = pd.read_sql(query_oil, connection)
df_holidays_events = pd.read_sql(query_holidays_events, connection)
df_stores = pd.read_sql(query_stores, connection)

# Display the first few rows of each DataFrame
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15840\1423495081.py:26: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_oil = pd.read_sql(query_oil, connection)
# C:\Users\user\AppData\Local\Temp\ipykernel_15840\1423495081.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_holidays_events = pd.read_sql(query_holidays_events, connection)
# C:\Users\user\AppData\Local\Temp\ipykernel_15840\1423495081.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_stores = pd.read_sql(query_stores, connection)

# %%
df_oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02   93.139999
# 2  2013-01-03   92.970001
# 3  2013-01-04   93.120003
# 4  2013-01-07   93.199997

# %%
df_holidays_events.head()
# Out:
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
df_stores.head()
# Out:
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
# imports From One Drive

df_sample = pd.read_csv('C:\\Users\\user\\Downloads\\Extracts\\LP3 Datasets\\sample_submission.csv')

df_sample.head()
# Out:
#         id  sales
# 0  3000888    0.0
# 1  3000889    0.0
# 2  3000890    0.0
# 3  3000891    0.0
# 4  3000892    0.0

# %%
df_test = pd.read_csv('C:\\Users\\user\\Downloads\\Extracts\\LP3 Datasets\\test.csv')

df_test.head()
# Out:
#         id        date  store_nbr      family  onpromotion
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0
# 1  3000889  2017-08-16          1   BABY CARE            0
# 2  3000890  2017-08-16          1      BEAUTY            2
# 3  3000891  2017-08-16          1   BEVERAGES           20
# 4  3000892  2017-08-16          1       BOOKS            0

# %%
df_train = pd.read_csv('C:\\Users\\user\\Downloads\\store-sales-forecasting\\train.csv')

df_train.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
df_transact = pd.read_csv('C:\\Users\\user\\Downloads\\store-sales-forecasting\\transactions.csv')

df_transact.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %% [markdown]
# ### EDA - Exploratory Data Analysis
#
# ### Checking Null values and data type on the data sets

# %%
df_oil.isnull().sum()
# Out:
# date           0
# dcoilwtico    43
# dtype: int64

# %%
df_oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
df_holidays_events.isnull().sum()
# Out:
# date           0
# type           0
# locale         0
# locale_name    0
# description    0
# transferred    0
# dtype: int64

# %%
df_holidays_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         350 non-null    object
#  1   type         350 non-null    object
#  2   locale       350 non-null    object
#  3   locale_name  350 non-null    object
#  4   description  350 non-null    object
#  5   transferred  350 non-null    bool
# dtypes: bool(1), object(5)
# memory usage: 14.1+ KB

# %%
df_stores.isnull().sum()
# Out:
# store_nbr    0
# city         0
# state        0
# type         0
# cluster      0
# dtype: int64

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   store_nbr  54 non-null     int64
#  1   city       54 non-null     object
#  2   state      54 non-null     object
#  3   type       54 non-null     object
#  4   cluster    54 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.2+ KB

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   store_nbr  54 non-null     int64
#  1   city       54 non-null     object
#  2   state      54 non-null     object
#  3   type       54 non-null     object
#  4   cluster    54 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.2+ KB

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28512 entries, 0 to 28511
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      28512 non-null  int64
#  1   sales   28512 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 445.6 KB

# %%
df_test.isnull().sum()
# Out:
# id             0
# date           0
# store_nbr      0
# family         0
# onpromotion    0
# dtype: int64

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28512 entries, 0 to 28511
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           28512 non-null  int64
#  1   date         28512 non-null  object
#  2   store_nbr    28512 non-null  int64
#  3   family       28512 non-null  object
#  4   onpromotion  28512 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 1.1+ MB

# %%
df_train.isnull().sum()
# Out:
# id             0
# date           0
# store_nbr      0
# family         0
# sales          0
# onpromotion    0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000888 entries, 0 to 3000887
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         object
#  2   store_nbr    int64
#  3   family       object
#  4   sales        float64
#  5   onpromotion  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 137.4+ MB

# %%
df_transact.isnull().sum()
# Out:
# date            0
# store_nbr       0
# transactions    0
# dtype: int64

# %%
df_transact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  object
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# **Checking all the shape of all the data Frames**

# %%
#Getting the shape of the datasets
print("Train dataset shape:", df_train.shape)
print("Test dataset shape:", df_test.shape)
print("Transactions dataset shape:", df_transact.shape)
print("Stores dataset shape:", df_stores.shape)
print("Oil dataset shape:", df_oil.shape)
print("Holiday Events dataset shape:", df_holidays_events.shape)

#Columns in the datasets
print("\nTrain dataset columns:", df_train.columns)
print("Test dataset columns:", df_test.columns)
print("Transactions dataset columns:", df_transact.columns)
print("Stores dataset columns:", df_stores.columns)
print("Oil dataset columns:", df_oil.columns)
print("Holiday Events dataset columns:", df_holidays_events.columns)
# Out:
# Train dataset shape: (3000888, 6)
# Test dataset shape: (28512, 5)
# Transactions dataset shape: (83488, 3)
# Stores dataset shape: (54, 5)
# Oil dataset shape: (1218, 2)
# Holiday Events dataset shape: (350, 6)
#
# Train dataset columns: Index(['id', 'date', 'store_nbr', 'family', 'sales', 'onpromotion'], dtype='object')
# Test dataset columns: Index(['id', 'date', 'store_nbr', 'family', 'onpromotion'], dtype='object')
# Transactions dataset columns: Index(['date', 'store_nbr', 'transactions'], dtype='object')
# Stores dataset columns: Index(['store_nbr', 'city', 'state', 'type', 'cluster'], dtype='object')
# Oil dataset columns: Index(['date', 'dcoilwtico'], dtype='object')
# Holiday Events dataset columns: Index(['date', 'type', 'locale', 'locale_name', 'description', 'transferred'], dtype='object')

# %% [markdown]
# *The stores datset has a type column, which is different from the type column in the holiday datset*

# %% [markdown]
# **Basic statistics of the datasets**

# %%
#Basic statistics of the datasets

print("Train dataset summary statistics:")
print(df_train.describe())

print("\nTest dataset summary statistics:")
print(df_test.describe())

print("\nTransactions dataset summary statistics:")
print(df_transact.describe())

print("\nStores dataset summary statistics:")
print(df_stores.describe())

print("\nOil dataset summary statistics:")
print(df_oil.describe())

print("\nHoliday Events dataset summary statistics:")
print(df_holidays_events.describe())
# Out:
# Train dataset summary statistics:
#                  id     store_nbr         sales   onpromotion
# count  3.000888e+06  3.000888e+06  3.000888e+06  3.000888e+06
# mean   1.500444e+06  2.750000e+01  3.577757e+02  2.602770e+00
# std    8.662819e+05  1.558579e+01  1.101998e+03  1.221888e+01
# min    0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    7.502218e+05  1.400000e+01  0.000000e+00  0.000000e+00
# 50%    1.500444e+06  2.750000e+01  1.100000e+01  0.000000e+00
# 75%    2.250665e+06  4.100000e+01  1.958473e+02  0.000000e+00
# max    3.000887e+06  5.400000e+01  1.247170e+05  7.410000e+02
#
# Test dataset summary statistics:
#                  id     store_nbr   onpromotion
# count  2.851200e+04  28512.000000  28512.000000
# mean   3.015144e+06     27.500000      6.965383
# std    8.230850e+03     15.586057     20.683952
# min    3.000888e+06      1.000000      0.000000
# 25%    3.008016e+06     14.000000      0.000000
# 50%    3.015144e+06     27.500000      0.000000
# ...

# %% [markdown]
# ## **Summary of Observations Across Tables:**
#
# **Common Observations:**
#
# *All datasets include a 'date' column, indicating temporal information.*
# *The dates in the 'date' column range from January 1, 2013, to August 31, 2017 with median date of May 2, 2015, indicating a balanced distribution of dates within the dataset. Some 'date' columns have NaN mean or standard deviation, suggesting potential issues with data types or non-numeric values.*
#
# **Holiday Events Dataset:**
#
# *Contains 350 observations related to holidays/events.*
# *'type' column has 6 unique values, with 'Holiday' occurring 221 times.*
# *'locale' column has 3 unique values, with 'National' occurring 174 times.*
# *'locale_name' column has 24 unique values, with 'Ecuador' occurring 174 times.*
# *'description' column has 103 unique values, with 'Carnaval' occurring 10 times.*
# *'transferred' column has 2 unique values ('True' and 'False'), with 'False' occurring 338 times.*
# *The 'type', 'locale', 'locale_name', 'description', and 'transferred' columns have NaN values in the 'unique', 'top', and 'freq' rows, indicating that these columns are categorical.*
#
# **Crude Oil Price Dataset:**
#
# *Contains 1,218 observations related to WTI crude oil prices.*
# *'dcoilwtico' column has 1,175 non-null values.The minimum crude oil price is $26.19, and the maximum is $110.62 with the median price of $53.19, suggesting that half of the observations have crude oil prices below this value.*
# *The dataset has some missing values in the 'dcoilwtico' column, as indicated by the difference in counts between 'date' and 'dcoilwtico'.*
# *The standard deviation for 'dcoilwtico' is $25.63, suggesting variability in the crude oil prices.*
#
# **Store and Cluster Dataset:**
#
# *Includes information for 54 stores, numbered from 1 to 54 and their cluster assignments and median store number of approximately 27.5, indicating the distribution of store numbers is centered around this value.*
# *'store_nbr' ranges from 1 to 54, with a median of approximately 27.5. The median cluster assignment is approximately 8.5, suggesting that half of the stores belong to clusters below this value and half to clusters above*
# *Standard deviations indicate variability in store numbers and cluster assignments.*
#
# **Store Transactions Dataset:**
#
# *Contains 83,488 observations related to store transactions.*
# *'store_nbr' ranges from 1 to 54, with a median of approximately 27 suggesting a balanced distribution of store numbers.*
# **The 'transactions' column has a wide range of values, ranging from 5 to 8,359, with the maximum being 8,359, indicating potential outliers or a diverse set of store transaction counts with a median of 1,393 indicating half of the observations have transaction counts below this value.*
# *Standard deviation for 'transactions' is relatively high (963.29), indicating variability.*
#
# **Train Dataset(ID, Date, Store, Sales, and On Promotion):**
#
# *Contains 3,000,888 observations related to store sales.*
# *'store_nbr' ranges from 1 to the maximum value in the dataset, with a median of approximately 2015 indicating a balanced distribution of store numbers..*
# *'sales' range from 0 to 124,717, with a median of 11 suggesting half of the observations have sales below this value. The column has a relatively high standard deviation (15.59), indicating variability in sales values.*
# *'onpromotion' is a categorical variable (0 or 1), with a median and 75th percentile value of 0 and  a relatively high maximum value (741), suggesting potential outliers or a wide range of values.*
#
# **Test Dataset(ID, Date, Store, and On Promotion):**
#
# *Contains 28,512 observations related to store information and promotion status.*
# *'store_nbr' ranges from 1 to the maximum value in the dataset, with a median of approximately 27.5.*
# *'onpromotion' is a categorical variable (0 or 1), with a median and 75th percentile value of 0 and a relatively high standard deviation (20.68), indicating variability in onpromotion values. The column has a relatively high maximum value (646), suggesting potential outliers or a wide range of values*
# *Some 'date' columns have NaN standard deviation, indicating potential issues.*
#
# **Overall Notes:**
#
# *Datasets may contain NaN values, particularly in categorical columns.*
# *Date columns in some datasets may have non-numeric data or unrecognized data types.*
# *Standard deviations and wide value ranges in certain columns indicate variability and potential outliers.*
# *Further context and domain-specific knowledge are needed for a comprehensive understanding of the data*

# %%
## Missing Values

print("Missing values in Train dataset:")
print(df_train.isnull().sum())

print("\nMissing values in Test dataset:")
print(df_test.isnull().sum())

print("\nMissing values in Transactions dataset:")
print(df_transact.isnull().sum())

print("\nMissing values in Stores dataset:")
print(df_stores.isnull().sum())

print("\nMissing values in Oil dataset:")
print(df_oil.isnull().sum())

print("\nMissing values in Holiday Events dataset:")
print(df_holidays_events.isnull().sum())
# Out:
# Missing values in Train dataset:
# id             0
# date           0
# store_nbr      0
# family         0
# sales          0
# onpromotion    0
# dtype: int64
#
# Missing values in Test dataset:
# id             0
# date           0
# store_nbr      0
# family         0
# onpromotion    0
# dtype: int64
#
# Missing values in Transactions dataset:
# date            0
# store_nbr       0
# transactions    0
# dtype: int64
#
# Missing values in Stores dataset:
# store_nbr    0
# city         0
# state        0
# type         0
# cluster      0
# dtype: int64
#
# Missing values in Oil dataset:
# date           0
# dcoilwtico    43
# dtype: int64
#
# Missing values in Holiday Events dataset:
# date           0
# type           0
# locale         0
# locale_name    0
# description    0
# transferred    0
# dtype: int64

# %%
## Unique values for each dataset

print("Unique values in Train dataset:")
print(df_train.nunique())

print("\nUnique values in Test dataset:")
print(df_test.nunique())

print("\nUnique values in Transactions dataset:")
print(df_transact.nunique())

print("\nUnique values in Stores dataset:")
print(df_stores.nunique())

print("\nUnique values in Oil dataset:")
print(df_oil.nunique())

print("\nUnique values in Holiday Events dataset:")
print(df_holidays_events.nunique())
# Out:
# Unique values in Train dataset:
# id             3000888
# date              1684
# store_nbr           54
# family              33
# sales           379610
# onpromotion        362
# dtype: int64
#
# Unique values in Test dataset:
# id             28512
# date              16
# store_nbr         54
# family            33
# onpromotion      212
# dtype: int64
#
# Unique values in Transactions dataset:
# date            1682
# store_nbr         54
# transactions    4993
# dtype: int64
#
# Unique values in Stores dataset:
# store_nbr    54
# city         22
# state        16
# type          5
# cluster      17
# dtype: int64
#
# Unique values in Oil dataset:
# date          1218
# dcoilwtico     998
# dtype: int64
#
# Unique values in Holiday Events dataset:
# date           312
# type             6
# locale           3
# locale_name     24
# description    103
# transferred      2
# dtype: int64

# %%
## Checking for datatypes each dataset

print("Train dataset columns data types:")
print(df_train.dtypes)

print("\nTest dataset data types:")
print(df_test.dtypes)

print("\nTransactions dataset data types:")
print(df_transact.dtypes)

print("\nStores dataset data types:")
print(df_stores.dtypes)

print("\nOil dataset data types:")
print(df_oil.dtypes)

print("\nHoliday Events dataset data types:")
print(df_holidays_events.dtypes)
# Out:
# Train dataset columns data types:
# id               int64
# date            object
# store_nbr        int64
# family          object
# sales          float64
# onpromotion      int64
# dtype: object
#
# Test dataset data types:
# id              int64
# date           object
# store_nbr       int64
# family         object
# onpromotion     int64
# dtype: object
#
# Transactions dataset data types:
# date            object
# store_nbr        int64
# transactions     int64
# dtype: object
#
# Stores dataset data types:
# store_nbr     int64
# city         object
# state        object
# type         object
# cluster       int64
# dtype: object
#
# Oil dataset data types:
# date           object
# dcoilwtico    float64
# dtype: object
#
# Holiday Events dataset data types:
# date           object
# type           object
# locale         object
# locale_name    object
# description    object
# transferred      bool
# dtype: object

# %% [markdown]
# ## **Data Preprocessing**
#
# ### **Data Preprocessing  on train dataset**

# %%
#Overview of the train dataset
df_train.head(5)
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
# view info
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000888 entries, 0 to 3000887
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         object
#  2   store_nbr    int64
#  3   family       object
#  4   sales        float64
#  5   onpromotion  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 137.4+ MB

# %%
#Converting the date column into datetime datatype
df_train['date'] = pd.to_datetime(df_train['date'])

# %%
df_train.isna().sum()
# Out:
# id             0
# date           0
# store_nbr      0
# family         0
# sales          0
# onpromotion    0
# dtype: int64

# %%
#Unique values in the promotion column
df_train['onpromotion'].nunique()
# Out:
# 362

# %%
#Checking for duplicates
df_train.duplicated().sum()
# Out:
# 0

# %%
# format numerical columns to 2 decimal places with comma separator
pd.options.display.float_format = '{:,.2f}'.format

# statistics for numerical columns
df_train.describe()
# Out:
#                 id                           date    store_nbr        sales  \
# count 3,000,888.00                        3000888 3,000,888.00 3,000,888.00
# mean  1,500,443.50  2015-04-24 08:27:04.703088384        27.50       357.78
# min           0.00            2013-01-01 00:00:00         1.00         0.00
# 25%     750,221.75            2014-02-26 18:00:00        14.00         0.00
# 50%   1,500,443.50            2015-04-24 12:00:00        27.50        11.00
# 75%   2,250,665.25            2016-06-19 06:00:00        41.00       195.85
# max   3,000,887.00            2017-08-15 00:00:00        54.00   124,717.00
# std     866,281.89                            NaN        15.59     1,102.00
#
#        onpromotion
# count 3,000,888.00
# mean          2.60
# min           0.00
# 25%           0.00
# 50%           0.00
# 75%           0.00
# max         741.00
# std          12.22

# %% [markdown]
# ### **Plotting frequencies of data point on yearly/monthly basis**

# %%
# copy train dataset so that we work with a copy, not the original
train_copy = df_train.copy()

# extracting the year column
train_copy['year'] = pd.to_datetime(df_train['date']).dt.year

# Grouping by year and count the data points
year_data = train_copy.groupby('year').size().reset_index(name='counts')

# Plotting the data
fig, ax = plt.subplots(figsize=(8, 4))
ax.bar(year_data['year'], year_data['counts'], color='blue')
ax.set_xticks(year_data['year'])
ax.set_title('Count of Number of Data Points Each Year')
ax.set_xlabel('Year')
ax.set_ylabel('Year Counts')

plt.show()

# %% [markdown]
# *There has been a uniformity of data counts from 2013-2016 but the count dropped in 2017*

# %%
# extracting the month
train_copy['month'] = pd.to_datetime(train_copy['date']).dt.month

# Grouping by month and count the data points
monthly_data = train_copy.groupby('month').size().reset_index(name='counts')

# Renaming the month values for labeling
month_names = [
    'January', 'February', 'March', 'April', 'May', 'June',
    'July', 'August', 'September', 'October', 'November', 'December'
]
monthly_data['month'] = monthly_data['month'].apply(lambda x: month_names[x - 1])

# Plotting the data
fig, ax = plt.subplots(figsize=(8, 4))
ax.bar(monthly_data['month'], monthly_data['counts'], color='blue')
ax.set_title('Count of Number of Data Points Each Month')
ax.set_xlabel('Months')
ax.set_ylabel('Monthly Counts')

plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Ensure labels are not cut off
plt.show()

# %% [markdown]
# *There is some uniformity in distribution of datapoints across the months*

# %% [markdown]
# ### **Total sales by store**

# %%
# Filter rows where unit_sales > 0
train_copy = train_copy[df_train['sales'] > 0]

# Group by 'store_nbr' and calculate the sum of 'unit_sales'
store_unit_sales = train_copy.groupby('store_nbr')['sales'].sum().reset_index()

# Set the figure size
sns.set(rc={'figure.figsize': (12, 4)})

# Create a barplot
sns.barplot(x='store_nbr', y='sales', data=store_unit_sales, palette='rainbow')

# Set titles and labels
plt.title('Total Sales per Store')
plt.xlabel('Stores')
plt.ylabel('Total Sales')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15840\1976147666.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='store_nbr', y='sales', data=store_unit_sales, palette='rainbow')

# %% [markdown]
# *We can say Store number 3,44,45,46,47,48,49, 51 have the highest volume of sales*

# %% [markdown]
# ### **Unit sales daily**

# %%
# Filter rows where unit_sales > 0
train_copy = train_copy[train_copy['sales'] > 0]

# Group by 'date' and calculate the sum of 'sales'
sales_date_agg = train_copy.groupby('date')['sales'].sum().reset_index()

# Create a lineplot using Plotly Express
fig = px.line(sales_date_agg, x='date', y='sales', title='Plot of Total Sales Over Time (Daily)')
fig.update_layout(width=1200, height=600)

# Add a range slider
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
# Show the plot
fig.show()

# %% [markdown]
# *Upward trend year on year*

# %% [markdown]
# ### **Checking for the completeness of the dates in the train dataset**

# %%
#Checking for the minimum date
df_train['date'].min()
# Out:
# Timestamp('2013-01-01 00:00:00')

# %%
#The maximum date 
df_train['date'].max()
# Out:
# Timestamp('2017-08-15 00:00:00')

# %%
# #Converting the date column into date
df_train['date'] =df_train['date'].dt.date

# %%
#Checking for the range of the dates column
dates_range = pd.date_range(start=df_train['date'].min(),end=df_train['date'].max())
dates_range
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10',
#                ...
#                '2017-08-06', '2017-08-07', '2017-08-08', '2017-08-09',
#                '2017-08-10', '2017-08-11', '2017-08-12', '2017-08-13',
#                '2017-08-14', '2017-08-15'],
#               dtype='datetime64[ns]', length=1688, freq='D')

# %%
#Checking for the missing dates
dates_missing = list(set(dates_range.date) - set(df_train['date'].unique()))
print(dates_missing)
# Out:
# [datetime.date(2016, 12, 25), datetime.date(2015, 12, 25), datetime.date(2013, 12, 25), datetime.date(2014, 12, 25)]

# %%
#Checking for the missing dates
dates_missing = set(dates_range.date) - set(df_train['date'].unique())
dates_missing
# Out:
# {datetime.date(2013, 12, 25),
#  datetime.date(2014, 12, 25),
#  datetime.date(2015, 12, 25),
#  datetime.date(2016, 12, 25)}

# %%
#Creating a new dataframe with the values in the date range
new_df = pd.DataFrame(index=dates_range)

# %%
# Converting the index of new_df to datetime64 data type
new_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2013-01-01 00:00:00, 2013-01-02 00:00:00, 2013-01-03 00:00:00, 2013-01-04 00:00:00, 2013-01-05 00:00:00]

# %%
#Shape of the new dataframe
new_df.shape
# Out:
# (1688, 0)

# %% [markdown]
# *To preserve the temporal order of the data, the imputation used is backwardfill. Interpolation in Python is a technique used to estimate unknown data points between two known data points. Backward fill is an approach where missing values are filled with the next available observation in the dataset (Agrawal, 2022).By filling missing values with the next available observation, the imputed values maintain the temporal sequence of the data.*

# %%
# Convert 'date' column in train DataFrame to datetime format
df_train['date'] = pd.to_datetime(df_train['date'])
#Mergning the missing dates with the train dataset
train_merged = new_df.merge(df_train, how='left', left_index=True, right_on='date')
train_merged.head()
# Out:
#        id       date  store_nbr      family  sales  onpromotion
# 0.00 0.00 2013-01-01       1.00  AUTOMOTIVE   0.00         0.00
# 1.00 1.00 2013-01-01       1.00   BABY CARE   0.00         0.00
# 2.00 2.00 2013-01-01       1.00      BEAUTY   0.00         0.00
# 3.00 3.00 2013-01-01       1.00   BEVERAGES   0.00         0.00
# 4.00 4.00 2013-01-01       1.00       BOOKS   0.00         0.00

# %%
train_merged.isna().sum()
# Out:
# id             4
# date           0
# store_nbr      4
# family         4
# sales          4
# onpromotion    4
# dtype: int64

# %%
# Sort the merged DataFrame by date
train_merged = train_merged.sort_values('date')
# Resetting the index
train_merged = train_merged.reset_index(drop=True)
train_merged.head()
# Out:
#         id       date  store_nbr        family  sales  onpromotion
# 0     0.00 2013-01-01       1.00    AUTOMOTIVE   0.00         0.00
# 1 1,194.00 2013-01-01      42.00   CELEBRATION   0.00         0.00
# 2 1,193.00 2013-01-01      42.00  BREAD/BAKERY   0.00         0.00
# 3 1,192.00 2013-01-01      42.00         BOOKS   0.00         0.00
# 4 1,191.00 2013-01-01      42.00     BEVERAGES   0.00         0.00

# %%
# Performing backfill interpolation on the merged DataFrame
train_merged_interpolated = train_merged.interpolate(method='bfill')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15840\2416794339.py:2: FutureWarning:
#
# DataFrame.interpolate with method=bfill is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.

# %%
train_merged_interpolated.head()
# Out:
#         id       date  store_nbr        family  sales  onpromotion
# 0     0.00 2013-01-01       1.00    AUTOMOTIVE   0.00         0.00
# 1 1,194.00 2013-01-01      42.00   CELEBRATION   0.00         0.00
# 2 1,193.00 2013-01-01      42.00  BREAD/BAKERY   0.00         0.00
# 3 1,192.00 2013-01-01      42.00         BOOKS   0.00         0.00
# 4 1,191.00 2013-01-01      42.00     BEVERAGES   0.00         0.00

# %%
train_merged_interpolated.isna().sum()
# Out:
# id             0
# date           0
# store_nbr      0
# family         0
# sales          0
# onpromotion    0
# dtype: int64

# %%
train_merged_interpolated.duplicated().sum()
# Out:
# 0

# %%
train_merged_interpolated['date'].nunique()
# Out:
# 1688

# %%
train_merged_interpolated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000892 entries, 0 to 3000891
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           float64
#  1   date         datetime64[ns]
#  2   store_nbr    float64
#  3   family       object
#  4   sales        float64
#  5   onpromotion  float64
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 137.4+ MB

# %% [markdown]
# ### **The Test Dataset**
#
# *The test data, has the same features as the training data, except sales,  which we will predict the target sales for the dates in this file.*
#
# *The dates in the test data are for the 15 days after the last date in the training data.*

# %%
# viewing first 5 rows
df_test.head()
# Out:
#         id        date  store_nbr      family  onpromotion
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0
# 1  3000889  2017-08-16          1   BABY CARE            0
# 2  3000890  2017-08-16          1      BEAUTY            2
# 3  3000891  2017-08-16          1   BEVERAGES           20
# 4  3000892  2017-08-16          1       BOOKS            0

# %%
# view basic info
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28512 entries, 0 to 28511
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           28512 non-null  int64
#  1   date         28512 non-null  object
#  2   store_nbr    28512 non-null  int64
#  3   family       28512 non-null  object
#  4   onpromotion  28512 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 1.1+ MB

# %%
# checking for missing values

df_test.isna().sum()
# Out:
# id             0
# date           0
# store_nbr      0
# family         0
# onpromotion    0
# dtype: int64

# %% [markdown]
# ### **Data Preprocessing on Oil Dataset**
#
# *Daily oil price which includes values during both the train and test data timeframes. (Ecuador is an oil-dependent country and its economical health is highly vulnerable to shocks in oil prices.)*

# %%
df_oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
df_oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
#Converting date to date type
df_oil['date']=pd.to_datetime(df_oil['date'])

# %%
df_oil.isna().sum()
# Out:
# date           0
# dcoilwtico    43
# dtype: int64

# %%
#percentage of the missing data
(df_oil.isna().sum()*100)/len(df_oil)
# Out:
# date         0.00
# dcoilwtico   3.53
# dtype: float64

# %%
# Oil prices over time

ax = df_oil.groupby(['date'], as_index=False)["dcoilwtico"].sum().plot(
    "date", "dcoilwtico", figsize=(10,4), title="Oil prices over time", color='blue')

plt.tick_params(axis='x', labelrotation=45)

# %% [markdown]
# **Checking for the completeness of the dates in the oil dataset**

# %%
#Convert into date data type
df_oil['date'] =df_oil['date'].dt.date

# %%
#The start date
df_oil['date'].min()
# Out:
# datetime.date(2013, 1, 1)

# %%
#The end date
df_oil['date'].max()
# Out:
# datetime.date(2017, 8, 31)

# %%
oil_date_range = pd.date_range(start=df_oil['date'].min(),end=df_oil['date'].max())
oil_date_range
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10',
#                ...
#                '2017-08-22', '2017-08-23', '2017-08-24', '2017-08-25',
#                '2017-08-26', '2017-08-27', '2017-08-28', '2017-08-29',
#                '2017-08-30', '2017-08-31'],
#               dtype='datetime64[ns]', length=1704, freq='D')

# %%
missing_oil_dates = set(oil_date_range.date) - set(df_oil['date'].unique())
missing_oil_dates
# Out:
# {datetime.date(2013, 1, 5),
#  datetime.date(2013, 1, 6),
#  datetime.date(2013, 1, 12),
#  datetime.date(2013, 1, 13),
#  datetime.date(2013, 1, 19),
#  datetime.date(2013, 1, 20),
#  datetime.date(2013, 1, 26),
#  datetime.date(2013, 1, 27),
#  datetime.date(2013, 2, 2),
#  datetime.date(2013, 2, 3),
#  datetime.date(2013, 2, 9),
#  datetime.date(2013, 2, 10),
#  datetime.date(2013, 2, 16),
#  datetime.date(2013, 2, 17),
#  datetime.date(2013, 2, 23),
#  datetime.date(2013, 2, 24),
#  datetime.date(2013, 3, 2),
#  datetime.date(2013, 3, 3),
#  datetime.date(2013, 3, 9),
#  datetime.date(2013, 3, 10),
#  datetime.date(2013, 3, 16),
#  datetime.date(2013, 3, 17),
#  datetime.date(2013, 3, 23),
#  datetime.date(2013, 3, 24),
#  datetime.date(2013, 3, 30),
#  datetime.date(2013, 3, 31),
#  datetime.date(2013, 4, 6),
#  datetime.date(2013, 4, 7),
#  datetime.date(2013, 4, 13),
#  datetime.date(2013, 4, 14),
#  datetime.date(2013, 4, 20),
#  datetime.date(2013, 4, 21),
# ...

# %%
df_oil['date'].nunique()
# Out:
# 1218

# %%
range_df =  pd.DataFrame(index=oil_date_range)
range_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2013-01-01 00:00:00, 2013-01-02 00:00:00, 2013-01-03 00:00:00, 2013-01-04 00:00:00, 2013-01-05 00:00:00]

# %%
# Convert 'date' column in train DataFrame to datetime format
df_oil['date'] = pd.to_datetime(df_oil['date'])

# %%
#Merging with the rest of the columns
oil_merged = range_df.merge(df_oil, how='left', left_index=True, right_on='date')
oil_merged.head()
# Out:
#            date  dcoilwtico
# 0.00 2013-01-01         NaN
# 1.00 2013-01-02       93.14
# 2.00 2013-01-03       92.97
# 3.00 2013-01-04       93.12
# NaN  2013-01-05         NaN

# %%
oil_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1704 entries, 0.0 to 1217.0
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1704 non-null   datetime64[ns]
#  1   dcoilwtico  1175 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 39.9 KB

# %%
# Sort the merged DataFrame by date
oil_merged = oil_merged.sort_values('date')
oil_merged
# Out:
#                date  dcoilwtico
# 0.00     2013-01-01         NaN
# 1.00     2013-01-02       93.14
# 2.00     2013-01-03       92.97
# 3.00     2013-01-04       93.12
# NaN      2013-01-05         NaN
# ...             ...         ...
# NaN      2017-08-27         NaN
# 1,214.00 2017-08-28       46.40
# 1,215.00 2017-08-29       46.46
# 1,216.00 2017-08-30       45.96
# 1,217.00 2017-08-31       47.26
#
# [1704 rows x 2 columns]

# %%
# Reset the index
oil_merged = oil_merged.reset_index(drop=True)
oil_merged
# Out:
#            date  dcoilwtico
# 0    2013-01-01         NaN
# 1    2013-01-02       93.14
# 2    2013-01-03       92.97
# 3    2013-01-04       93.12
# 4    2013-01-05         NaN
# ...         ...         ...
# 1699 2017-08-27         NaN
# 1700 2017-08-28       46.40
# 1701 2017-08-29       46.46
# 1702 2017-08-30       45.96
# 1703 2017-08-31       47.26
#
# [1704 rows x 2 columns]

# %%
# Perform linear interpolation on the merged DataFrame using bfill
oil_merged_interpolated = oil_merged.interpolate(method='bfill')

oil_merged_interpolated.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15840\2247267248.py:2: FutureWarning:
#
# DataFrame.interpolate with method=bfill is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#         date  dcoilwtico
# 0 2013-01-01       93.14
# 1 2013-01-02       93.14
# 2 2013-01-03       92.97
# 3 2013-01-04       93.12
# 4 2013-01-05       93.20

# %%
oil_merged_interpolated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1704 non-null   datetime64[ns]
#  1   dcoilwtico  1704 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 26.8 KB

# %% [markdown]
# ### **Data Preprocessing on the Holiday events Dataset**
#
# **Holidays and Events, with metadata**
#
# *NOTE: Pay special attention to the transferred column. A holiday that is transferred officially falls on that calendar day but was moved to another date by the government. A transferred day is more like a normal day than a holiday. To find the day that it was celebrated, look for the corresponding row where type is Transfer.*
#
# *For example, the holiday Independencia de Guayaquil was transferred from 2012-10-09 to 2012-10-12, which means it was celebrated on 2012-10-12. Days that are type Bridge are extra days that are added to a holiday (e.g., to extend the break across a long weekend). These are frequently made up by the type Work Day which is a day not normally scheduled for work (e.g., Saturday) that is meant to payback the Bridge.*
#
# *Additional holidays are days added a regular calendar holiday, for example, as typically happens around Christmas (making Christmas Eve a holiday).*

# %%
df_holidays_events.head()
# Out:
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
df_holidays_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         350 non-null    object
#  1   type         350 non-null    object
#  2   locale       350 non-null    object
#  3   locale_name  350 non-null    object
#  4   description  350 non-null    object
#  5   transferred  350 non-null    bool
# dtypes: bool(1), object(5)
# memory usage: 14.1+ KB

# %%
#Renaming the type column
df_holidays_events.rename(columns={'type':'holiday_type'},inplace=True)

#Converting the dates into datetume data type
df_holidays_events['date'] = pd.to_datetime(df_holidays_events['date'])

holiday_date_range = pd.date_range(start=df_holidays_events['date'].min(),end=df_holidays_events['date'].max())
holiday_date_range
# Out:
# DatetimeIndex(['2012-03-02', '2012-03-03', '2012-03-04', '2012-03-05',
#                '2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10', '2012-03-11',
#                ...
#                '2017-12-17', '2017-12-18', '2017-12-19', '2017-12-20',
#                '2017-12-21', '2017-12-22', '2017-12-23', '2017-12-24',
#                '2017-12-25', '2017-12-26'],
#               dtype='datetime64[ns]', length=2126, freq='D')

# %%
missing_holiday_dates = set(holiday_date_range.date) - set(df_holidays_events['date'].unique())
missing_holiday_dates
# Out:
# {datetime.date(2015, 8, 27),
#  datetime.date(2017, 1, 7),
#  datetime.date(2014, 6, 20),
#  datetime.date(2014, 11, 14),
#  datetime.date(2012, 6, 4),
#  datetime.date(2017, 7, 5),
#  datetime.date(2013, 3, 22),
#  datetime.date(2017, 3, 15),
#  datetime.date(2017, 3, 2),
#  datetime.date(2013, 10, 30),
#  datetime.date(2016, 8, 12),
#  datetime.date(2013, 12, 25),
#  datetime.date(2013, 7, 21),
#  datetime.date(2013, 6, 24),
#  datetime.date(2015, 12, 8),
#  datetime.date(2016, 8, 14),
#  datetime.date(2013, 8, 7),
#  datetime.date(2013, 2, 15),
#  datetime.date(2013, 12, 31),
#  datetime.date(2016, 9, 22),
#  datetime.date(2013, 10, 23),
#  datetime.date(2014, 1, 8),
#  datetime.date(2017, 11, 10),
#  datetime.date(2016, 5, 22),
#  datetime.date(2017, 9, 13),
#  datetime.date(2013, 5, 1),
#  datetime.date(2015, 1, 11),
#  datetime.date(2016, 12, 25),
#  datetime.date(2015, 1, 10),
#  datetime.date(2015, 2, 12),
#  datetime.date(2017, 6, 3),
#  datetime.date(2017, 11, 11),
# ...

# %%
#New dataframe with the date range
holiday_df =  pd.DataFrame(index=holiday_date_range)
holiday_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2012-03-02 00:00:00, 2012-03-03 00:00:00, 2012-03-04 00:00:00, 2012-03-05 00:00:00, 2012-03-06 00:00:00]

# %%
#merging
holiday_merged = holiday_df.merge(df_holidays_events, how='left', left_index=True, right_on='date')
holiday_merged.head()
# Out:
#            date holiday_type locale locale_name         description  \
# 0.00 2012-03-02      Holiday  Local       Manta  Fundacion de Manta
# NaN  2012-03-03          NaN    NaN         NaN                 NaN
# NaN  2012-03-04          NaN    NaN         NaN                 NaN
# NaN  2012-03-05          NaN    NaN         NaN                 NaN
# NaN  2012-03-06          NaN    NaN         NaN                 NaN
#
#      transferred
# 0.00       False
# NaN          NaN
# NaN          NaN
# NaN          NaN
# NaN          NaN

# %%
# Sort the merged DataFrame by date
holiday_merged = holiday_merged.sort_values('date')
# Resetting the index
holiday_merged = holiday_merged.reset_index(drop=True)
holiday_merged.head()
# Out:
#         date holiday_type locale locale_name         description transferred
# 0 2012-03-02      Holiday  Local       Manta  Fundacion de Manta       False
# 1 2012-03-03          NaN    NaN         NaN                 NaN         NaN
# 2 2012-03-04          NaN    NaN         NaN                 NaN         NaN
# 3 2012-03-05          NaN    NaN         NaN                 NaN         NaN
# 4 2012-03-06          NaN    NaN         NaN                 NaN         NaN

# %%
# Perform interpolation on the merged DataFrame using bfill
holiday_merged_interpolated = holiday_merged.interpolate(method='bfill')
holiday_merged_interpolated.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15840\2969984252.py:2: FutureWarning:
#
# DataFrame.interpolate with method=bfill is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#         date holiday_type    locale locale_name  \
# 0 2012-03-02      Holiday     Local       Manta
# 1 2012-03-03      Holiday  Regional    Cotopaxi
# 2 2012-03-04      Holiday  Regional    Cotopaxi
# 3 2012-03-05      Holiday  Regional    Cotopaxi
# 4 2012-03-06      Holiday  Regional    Cotopaxi
#
#                      description  transferred
# 0             Fundacion de Manta        False
# 1  Provincializacion de Cotopaxi        False
# 2  Provincializacion de Cotopaxi        False
# 3  Provincializacion de Cotopaxi        False
# 4  Provincializacion de Cotopaxi        False

# %%
holiday_merged_interpolated.nunique()
# Out:
# date            2126
# holiday_type       6
# locale             3
# locale_name       24
# description      103
# transferred        2
# dtype: int64

# %%
holiday_merged_interpolated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2164 entries, 0 to 2163
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2164 non-null   datetime64[ns]
#  1   holiday_type  2164 non-null   object
#  2   locale        2164 non-null   object
#  3   locale_name   2164 non-null   object
#  4   description   2164 non-null   object
#  5   transferred   2164 non-null   bool
# dtypes: bool(1), datetime64[ns](1), object(4)
# memory usage: 86.8+ KB

# %% [markdown]
# *A holiday that is transferred officially falls on that calendar day but was moved to another date by the government. A transferred day is more like a normal day than a holiday. To update the "date" column in the DataFrame, specifically for rows where the holiday is marked as "Transfer" in the "type" column.We can assign the value from the "transferred" column to the corresponding rows in the "date" column.*

# %% [markdown]
# ### **Preprocessing the Transcation Dataset**

# %%
df_transact.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
df_transact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  object
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ MB

# %%
df_transact.isna().sum()
# Out:
# date            0
# store_nbr       0
# transactions    0
# dtype: int64

# %%
# Visualize transactions over the years with plotly

fig = px.line(df_transact, y="transactions",x='date', title="Transaction data over time")

# enable range slider with range selector
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.show()

# %% [markdown]
# *Big spikes is transactions in december every year; indicates seasonality*

# %%
#Converting the dates into datetume data type
df_transact['date']=pd.to_datetime(df_transact['date'])

transactions_date_range = pd.date_range(start=df_transact['date'].min(),end=df_transact['date'].max())
transactions_date_range
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10',
#                ...
#                '2017-08-06', '2017-08-07', '2017-08-08', '2017-08-09',
#                '2017-08-10', '2017-08-11', '2017-08-12', '2017-08-13',
#                '2017-08-14', '2017-08-15'],
#               dtype='datetime64[ns]', length=1688, freq='D')

# %%
df_transact['date'].nunique()
# Out:
# 1682

# %%
transc_df =  pd.DataFrame(index=transactions_date_range)
transc_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2013-01-01 00:00:00, 2013-01-02 00:00:00, 2013-01-03 00:00:00, 2013-01-04 00:00:00, 2013-01-05 00:00:00]

# %%
# Convert 'date' column in train DataFrame to datetime format
df_transact['date'] = pd.to_datetime(df_transact['date'])

# %%
transactions_merged = transc_df.merge(df_transact, how='left', left_index=True, right_on='date')
transactions_merged.head()
# Out:
#            date  store_nbr  transactions
# 0.00 2013-01-01      25.00        770.00
# 1.00 2013-01-02       1.00      2,111.00
# 2.00 2013-01-02       2.00      2,358.00
# 3.00 2013-01-02       3.00      3,487.00
# 4.00 2013-01-02       4.00      1,922.00

# %%
# Sort the merged DataFrame by date
transactions_merged = transactions_merged.sort_values('date')
# Resetting the index
transactions_merged = transactions_merged.reset_index(drop=True)
transactions_merged.head()
# Out:
#         date  store_nbr  transactions
# 0 2013-01-01      25.00        770.00
# 1 2013-01-02      30.00        708.00
# 2 2013-01-02      31.00      1,401.00
# 3 2013-01-02      32.00        776.00
# 4 2013-01-02      33.00      1,163.00

# %%
# Perform interpolation on the merged DataFrame using bfill
transactions_merged_interpolated = transactions_merged.fillna(0)

transactions_merged_interpolated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83494 entries, 0 to 83493
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83494 non-null  datetime64[ns]
#  1   store_nbr     83494 non-null  float64
#  2   transactions  83494 non-null  float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 1.9 MB

# %%
transactions_merged_interpolated.nunique()
# Out:
# date            1688
# store_nbr         55
# transactions    4994
# dtype: int64

# %% [markdown]
# ### **Stores Datast**
#
# *Store metadata, including city, state, type, and cluster.*
#
# *Cluster is a grouping of similar stores.*

# %%
# viewing first 5 rows
df_stores.head()
# Out:
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
# view info
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   store_nbr  54 non-null     int64
#  1   city       54 non-null     object
#  2   state      54 non-null     object
#  3   type       54 non-null     object
#  4   cluster    54 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.2+ KB

# %%
# check for missing values

df_stores.isna().sum()
# Out:
# store_nbr    0
# city         0
# state        0
# type         0
# cluster      0
# dtype: int64

# %% [markdown]
# ## **Merging the Datasets**

# %%
#Merging interpolated train and interpolated oil datasets
Train = train_merged_interpolated.merge(oil_merged_interpolated,how='inner',on='date')
Train.head()
# Out:
#         id       date  store_nbr        family  sales  onpromotion  dcoilwtico
# 0     0.00 2013-01-01       1.00    AUTOMOTIVE   0.00         0.00       93.14
# 1 1,194.00 2013-01-01      42.00   CELEBRATION   0.00         0.00       93.14
# 2 1,193.00 2013-01-01      42.00  BREAD/BAKERY   0.00         0.00       93.14
# 3 1,192.00 2013-01-01      42.00         BOOKS   0.00         0.00       93.14
# 4 1,191.00 2013-01-01      42.00     BEVERAGES   0.00         0.00       93.14

# %%
df_stores.head()
# Out:
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
Train = Train.merge(df_stores[['store_nbr', 'state','city']], on=['store_nbr'], how='left')
Train.head()
# Out:
#         id       date  store_nbr        family  sales  onpromotion  \
# 0     0.00 2013-01-01       1.00    AUTOMOTIVE   0.00         0.00
# 1 1,194.00 2013-01-01      42.00   CELEBRATION   0.00         0.00
# 2 1,193.00 2013-01-01      42.00  BREAD/BAKERY   0.00         0.00
# 3 1,192.00 2013-01-01      42.00         BOOKS   0.00         0.00
# 4 1,191.00 2013-01-01      42.00     BEVERAGES   0.00         0.00
#
#    dcoilwtico      state    city
# 0       93.14  Pichincha   Quito
# 1       93.14      Azuay  Cuenca
# 2       93.14      Azuay  Cuenca
# 3       93.14      Azuay  Cuenca
# 4       93.14      Azuay  Cuenca
